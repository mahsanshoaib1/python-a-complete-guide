# %% [markdown]
# # Data visualization
#
# **step-1 importing libraries**

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **step-2 loading dataset**

# %%
kashti = sns.load_dataset("titanic")

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **step-3 plotting our graphs**
#
# ## lineplot

# %%
sns.lineplot(x= "fare", y= "age", data= kashti)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='age'>

# %%
sns.lineplot(x= kashti["fare"], y= kashti["age"])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='age'>

# %%
sns.lineplot(x= "pclass", y= "age", data= kashti)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.lineplot(x= "age", y= "pclass", data= kashti)
# Out:
# <AxesSubplot:xlabel='age', ylabel='pclass'>

# %%
sns.lineplot(x= "pclass", y= "age", data= kashti)
plt.title("Kashti ka data_set")
plt.show()

# %%
sns.lineplot(x= "age", y= "pclass", data= kashti)
plt.title("kashti ka dataset")
# plt.xlim(3)
plt.ylim(-1)
plt.show()

# %%
sns.lineplot(x= "age", y= "pclass", data= kashti)
plt.title("kashti ka dataset")
plt.show()

# %% [markdown]
# # barplot

# %%
col= kashti.columns
col
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.barplot(x= "survived", y= "fare", data= kashti, width=0.3)
plt.title("gender ka fare ky sath relation")
# Out:
# Text(0.5, 1.0, 'gender ka fare ky sath relation')

# %% [markdown]
# > # customization of barplot

# %%
df = sns.load_dataset("tips")
sns.barplot(x = df["sex"], y= df["size"],hue=df["time"],order= ("Female", "Male"),estimator="mean",
            palette="Set2", saturation=1, width= 0.5, errcolor="yellow", errwidth=3, capsize=0.05, dodge=True, alpha=1)
plt.xlabel("gender dia hy x pr")
plt.ylabel("Kitny bandy aaty hein")
plt.title("loog tip daity yaan nai")
plt.show()

# %%
# sns.barplot(x= "who", y= "age", data= kashti,  col = "class" , palette= "Set2", saturation = 2)
# plt.title("gender ka fare ky sath relation")

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x= "survived", y= "age", data= kashti)
plt.title("gender ka fare ky sath relation")
# Out:
# Text(0.5, 1.0, 'gender ka fare ky sath relation')

# %%
col
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.boxplot(x= "class" , y= "age", data= kashti)
plt.title("gender ka fare ky sath relation")
# Out:
# Text(0.5, 1.0, 'gender ka fare ky sath relation')

# %% [markdown]
# > # Customization of boxplot

# %%
a= [6,2,4,4,1,3,4,6,1,2,3,5,3,6,8,6,8]
b = [3,4,2,4,5,1,7,8,3,4,2,9,6,7,4,2,8]
c = ["Ali","Abdullah", "Qasim", "Ahsan", "Fatima"]

# %%
sns.boxplot(x= b,y=a,color="blue",palette="Set2", saturation=1, width=0.7, 
            dodge= True, fliersize=9, linewidth=1.3,whis=5)
plt.title("customize kr rha hoon apny plot ko")
plt.xlabel("b ki value di hy x pr")
plt.ylabel("a ki value di hy y pr")
plt.show()

# %%
sns.boxplot(x= b,y=a,color="blue",palette="Set2", saturation=1, width=0.7, 
            dodge= True, fliersize=9, linewidth=1.3,whis=5)
sns.set_style("ticks")
plt.title("customize kr rha hoon apny plot ko")
plt.xlabel("b ki value di hy x pr")
plt.ylabel("a ki value di hy y pr")
plt.show()

# %%
dict = {"Ahsan":25, "Ali":23, "Abdullah":30}
plt.box()
plt.show()

# %%
sns.boxenplot(x= "class" , y= "age", data= kashti,)
plt.title("gender ka fare ky sath relation")
# Out:
# Text(0.5, 1.0, 'gender ka fare ky sath relation')

# %%
sns.catplot(x= "class" , y= "age", data= kashti, kind= "boxen")
plt.title("gender ka fare ky sath relation")
# Out:
# Text(0.5, 1.0, 'gender ka fare ky sath relation')

# %%
sns.countplot(x= "who", data= kashti)
plt.title("gender ka fare ky sath relation")
# Out:
# Text(0.5, 1.0, 'gender ka fare ky sath relation')

# %%
sns.histplot( x = "age",  data= kashti)
plt.title("gender ka fare ky sath relation")
# Out:
# Text(0.5, 1.0, 'gender ka fare ky sath relation')

# %%
col
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.displot( x = "age",  data= kashti)
plt.title("gender ka fare ky sath relation")
# Out:
# Text(0.5, 1.0, 'gender ka fare ky sath relation')

# %%
sns.scatterplot(x = "age", y= "sibsp" ,data= kashti)
plt.title("gender ka fare ky sath relation")
# Out:
# Text(0.5, 1.0, 'gender ka fare ky sath relation')

# %%
g=sns.FacetGrid(kashti, row="sex", hue="who")
g=(g.map(plt.scatter, "age", "fare").add_legend())
plt.show()

# %%
tips= sns.load_dataset("tips")        # laoding dataset
fig = plt.scatter                    # plotting the graph
fig("day", "tip", c="size", data= tips) # mapping, giving the value of  x and y variable

plt.xlabel("gender")
plt.ylabel("day")
plt.title("tips ka dataset")
plt.colorbar()
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# sns.catplot(data=tips, x="size", y="tip", col= "sex", palette="Set2", kind= "boxplot",contrast=2, alpha_value=5)

# %%
# sns.dogplot(data= df, x="sex", y="tip", saturation=0 )

# %%
sns.kdeplot(data=tips, x="tip", y="total_bill", cbar=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.lmplot(data=tips, x= "total_bill", y="size", hue="sex",palette="Set1")

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

ks = sns.load_dataset("titanic")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=ks, kind="bar",
    x="sex", y="age", hue="who",
    errorbar="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="clarity", y="carat",
              color="c", order=clarity_ranking,
              scale="linear", data=diamonds)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='carat'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
iris = sns.load_dataset("iris")

# "Melt" the dataset to "long-form" or "tidy" representation
iris = pd.melt(iris, "species", var_name="measurement")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(
    data=iris, x="value", y="measurement", hue="species",
    dodge=True, alpha=.25, zorder=1, legend=False
)

# Show the conditional means, aligning each pointplot in the
# center of the strips by adjusting the width allotted to each
# category (.8 by default) by the number of hue levels
sns.pointplot(
    data=iris, x="value", y="measurement", hue="species",
    join=False, dodge=.8 - .8 / 3, palette="dark",
    markers="d", scale=.75, errorbar=None
)

# Improve the legend
sns.move_legend(
    ax, loc="lower right", ncol=3, frameon=True, columnspacing=1, handletextpad=0
)

# %%
data=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# > # barplot using matplotlib

# %%
sns.set_theme(style= "darkgrid",palette= "deep", font="sans-serif",color_codes= True, font_scale= 1.3,  )
fig = plt.bar(x= "sex",height="tip", data= data)
plt.show()

# %%
dic = {"Ahsan": 40, "Ali": 35, "Abdullah": 37}
a = dic.keys()
b = dic.values()
type(a)
# Out:
# dict_keys

# %%
sns.set_theme(style= "darkgrid",palette= "dark", font="sans-serif",color_codes= False, font_scale= 1.3 )
plot=plt.bar(dic.keys(), dic.values())
plt.xlabel("x pr naam diye huy hein")
plt.ylabel("y pr number diye hein ")
plt.title("dictionary ka title dy rha hoon")
plt.show()

# %% [markdown]
# > # scatterplot using matplotlib

# %%
a= [1,2,15,4,2,3,8,]
b = [2,11,2,14,5,1,1]
c = ["Ali","Abdullah", "Qasim", "Ahsan", "Fatima", "Sheraz", "Harmain"]
d = [12,13,14,15,16,4,5]
e = [40,43,35,50,20,15,30]

len(a)
# Out:
# 7

# %% [markdown]
# > a float or int value as color
#
# >and then show color bar

# %%
plt.grid(False)
plt.scatter(x=a, y=b)
plt.xlabel("a list hy.")

plt.ylabel("b bhi list hy.")


plt.show()

# %% [markdown]
# > # Customization of scatter plot

# %%
plt.grid(False)
plt.scatter(x=a, y=b, c=d)
plt.xlabel("a list hy.")

plt.ylabel("b bhi list hy.")

plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_10531/2938736107.py:7: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
plt.grid(False)
plt.scatter(x=a, y=b, c=d)
plt.xlabel("a list hy.")
plt.xlim(0,16)
plt.ylabel("b bhi list hy.")
plt.ylim(0,16)
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_10531/853115987.py:7: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
plt.grid(False)
plt.scatter(x=a, y=b, c=d, s=e,  marker="*", cmap="Set1", edgecolors="blue", linewidths=1, )
plt.xlabel("a list hy.")
plt.xlim(0,16)
plt.ylabel("b bhi list hy.")
plt.ylim(0,16)
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_10531/1387212252.py:7: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
plt.grid(False)
plt.scatter(x=a, y=b, c=d, s=e,  marker="*", cmap="Set1" )
plt.xlabel("a list hy.")
plt.xlim(0,16)
plt.ylabel("b bhi list hy.")
plt.ylim(0,16)
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_10531/3203110263.py:7: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
plt.grid(False)
plt.scatter(x=a, y=b, c=d, s=e,  marker="*", cmap="Set1", edgecolors="blue", linewidths=1, )
plt.xlabel("a list hy.")
plt.xlim(0,16)
plt.ylabel("b bhi list hy.")
plt.ylim(0,16)
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_10531/1387212252.py:7: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
plt.grid(False)
plt.scatter(x=a, y=b, c=d, s=e,  marker="*", cmap="Set1", edgecolors="blue", linewidths=1, )
plt.xlabel("a list hy.")
plt.xlim(0,16)
plt.ylabel("b bhi list hy.")
plt.ylim(0,16)
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_10531/1387212252.py:7: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
import seaborn as sns
df = sns.load_dataset("tips")
sns.pairplot(df, hue="sex", palette="Dark2" )

# %%
import seaborn as sns
df = sns.load_dataset("tips")
sns.pairplot(df, hue="sex", palette="Dark2", x_vars=["total_bill", "tip"] )

# %%
p = sns.scatterplot(data=df, x= "total_bill", y= "tip",Dot=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_14141/1480335580.py in <module>
# ----> 1 p = sns.scatterplot(data=df, x= "total_bill", y= "tip",Dot=False)
#
# ~/.local/lib/python3.10/site-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     757     # and we should probably do that here too
#     758     color = kwargs.pop("color", None)
# --> 759     kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
#     760
#     761     p.plot(ax, kwargs)
#
# ~/.local/lib/python3.10/site-packages/seaborn/utils.py in _default_color(method, hue, color, kws)
#     116         scout_x = scout_y = np.full(scout_size, np.nan)
#     117
# --> 118         scout = method(scout_x, scout_y, **kws)
# ...

# %%
p.add(sns.Line(), sns.PolyFit())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14141/1843082902.py in <module>
# ----> 1 p.add(sns.Line(), sns.PolyFit())
#
# NameError: name 'p' is not defined

# %%
sns.displot(data=df, x="total_bill", col="size", kde=True)

# %%
sns.kdeplot(data=df, x="size", y="tip")
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# ## Customization of plot using seaborn
#
# setting titles using seaborn

# %%
import seaborn as sns
penguins = sns.load_dataset("penguins")
sns.set_theme(style="ticks", font_scale=1.25)
g = sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="body_mass_g",
    palette="crest", marker="x", s=100,
)
g.set_axis_labels("Bill length (mm)", "Bill depth (mm)", labelpad=10)
g.legend.set_title("Body mass (g)")
g.figure.set_size_inches(6.5, 4.5)
g.ax.margins(.15)
g.despine(trim=True)

# %%
data = [["Ahsan", 41,526403],["Harmain", 43, 526436],
                ["Sheraz", 38, 526434]]

# %%
dict_1 = {"Names" : ["Ahsan", "Sheraz", "Harmain", "Ali", "Irtza", "Bhu ALi", "Zain"],
          "marks": [41,43,38, 36, 47, 26,25],
          "rollnumber":[526403, 526436, 526434,526440,526408,526447,526452 ]}
df8 = pd.DataFrame(dict_1)
df8
# Out:
#      Names  marks  rollnumber
# 0    Ahsan     41      526403
# 1   Sheraz     43      526436
# 2  Harmain     38      526434
# 3      Ali     36      526440
# 4    Irtza     47      526408
# 5  Bhu ALi     26      526447
# 6     Zain     25      526452

# %%
sns.set_theme(style="darkgrid", palette="dark", font_scale=1.5, color_codes= False)
sns.countplot(data=dict_1, x="marks")
# Out:
# <AxesSubplot:ylabel='count'>

# %%
sns.histplot(data=df8, x="marks")
sns.set_theme(style="darkgrid", palette="dark")
sns.barplot(data = dict_1, x= "Names", y= "marks", dodge=True,  width=0.4 )
plt.xlabel("Names")
plt.ylabel("Marks")
plt.title("bachon ky number")
plt.show()

# %%
sns.pairplot(df8, hue="Names")
